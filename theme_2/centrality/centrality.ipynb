# %% [markdown]
# ## Setting up database connection

# %% [markdown]
# Importing required python libraries

# %%
import os
import sys
sys.path.append(os.path.abspath('../../'))
from query_indicators import generate_save_path

import py2neo
from nesta.core.luigihacks.misctools import get_config
from nesta.core.orms.orm_utils import graph_session
import igraph as ig
import pandas as pd
import boto3

# %%
S3 = boto3.resource('s3')
SAVE_PATH = generate_save_path()  # EURITO collaborators: this is generated assuming you have stuck to the convention 'theme_x/something/something_else.ipynb'
BUCKET = 'eurito-indicators'  # EURITO collaborators: please don't change this
SAVE_RESULTS = True  # Set this to "False" when you want to view figures inline. When "True", results will be saved to S3.

# %% [markdown]
# Establish connection to the Neo4j database

# %%
conf = get_config('neo4j.config', 'neo4j')
gkwargs = dict(host=conf['host'], secure=True,
                auth=(conf['user'], conf['password']))

# %%
def _s3_savetable(df, object_path):
    """Upload the table to s3"""
    if not SAVE_RESULTS:
        return
    if len(df.columns) == 1:
        df.columns = ['value']
    #df = df / df.max().max()
    table_data = df.to_csv(sep='|').encode()
    obj = S3.Object(BUCKET, os.path.join(f'tables/{SAVE_PATH}', object_path))
    obj.put(Body=table_data)

# %% [markdown]
# ## Retrieving nodes from Neo4j

# %% [markdown]
# Create a graph object which will be used for our queries

# %%
with graph_session(**gkwargs) as tx:
    graph = tx.graph

# %% [markdown]
# Set the type of the node that should be retrieved. Available types are: "Project", "Organisation", "Publication", "Topic", "Report", "Datasets", "Software", "Proposal_Call". Simply change the word "Organisation" below to the required node type and re-run the cell.

# %% [markdown]
# **Nodes of type "Organisation" have the following fields:** <br>
# *name* - organisation name <br>
# *betw* - organisation centrality <br>
# *country_code* - 2 letter country code <br>
# *country_name* - country name <br>

# %%
node_type = "Organisation"

# %% [markdown]
# Create a list from the graph nodes.

# %%
node_list = list(graph.nodes.match(node_type))

# %% [markdown]
# Convert to dataframe, sort the table according to centrality column and print the top 15

# %%
node_table = pd.DataFrame(node_list)
node_table = node_table.drop("centrality", axis=1)
top_betw = node_table.sort_values(by=['betw'], ascending=False)
top_nodes = top_betw.head(15)
top_nodes
# Out:
#                betw country_code    country_name         id  \
# 51249  1.146743e+08           FR          France  999997930
# 51147  4.847232e+07           DE         Germany  999984059
# 51208  2.794104e+07           ES           Spain  999991722
# 51123  2.575960e+07           IT           Italy  999979500
# 51214  2.525885e+07           FR          France  999992401
# 51103  2.379738e+07           GB  United Kingdom  999977172
# 51150  2.335705e+07           GB  United Kingdom  999984350
# 51224  1.654897e+07           GB  United Kingdom  999993468
# 51121  1.572158e+07           CH     Switzerland  999979015
# 51205  1.507029e+07           BE         Belgium  999991334
# 1252   1.380564e+07           DE         Germany  888898380
# 51203  1.062566e+07           DK         Denmark  999991043
# 51072  1.043598e+07           CH     Switzerland  999973971
# 51082  9.158881e+06           GB  United Kingdom  999974941
# 51199  8.711779e+06           DK         Denmark  999990655
#
#                                                     name
# 51249  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# 51147  FRAUNHOFER GESELLSCHAFT ZUR FOERDERUNG DER ANG...
# 51208  AGENCIA ESTATAL CONSEJO SUPERIOR DEINVESTIGACI...
# 51123                 CONSIGLIO NAZIONALE DELLE RICERCHE
# 51214  COMMISSARIAT A L ENERGIE ATOMIQUE ET AUX ENERG...
# 51103  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...
# 51150  THE CHANCELLOR, MASTERS AND SCHOLARS OF THE UN...
# 51224  IMPERIAL COLLEGE OF SCIENCE TECHNOLOGY AND MED...
# 51121      EIDGENOESSISCHE TECHNISCHE HOCHSCHULE ZUERICH
# 51205                     KATHOLIEKE UNIVERSITEIT LEUVEN
# 1252   MAX-PLANCK-GESELLSCHAFT ZUR FORDERUNG DER WISS...
# 51203                             KOBENHAVNS UNIVERSITET
# 51072           ECOLE POLYTECHNIQUE FEDERALE DE LAUSANNE
# 51082                        THE UNIVERSITY OF EDINBURGH
# 51199                      DANMARKS TEKNISKE UNIVERSITET

# %% [markdown]
# Save the generated table into S3 bucket

# %%
 _s3_savetable(top_nodes, object_path=f'{node_type}/organisation_centrality_top15.csv')

# %% [markdown]
# **Nodes of type "Project" have the following fields:** <br>
# *acronym* - project acronym <br>
# *betw* - project centrality <br>
# *ec_contribution* - funding by EC, mio EUR <br>
# *start_date_code, end_date_code* - project start and end date <br>
# *framework, funded_under, funding_scheme* - funding framework and program <br>
# *grant_num* - 6 digit grant number <br>
# *objective* - project objective <br>
# *project_description* - project description <br>
# *rcn* - project identificator <br>
# *status* - project status (e.g. closed, ongoing) <br>
# *total_cost* - total budget, mio EUR <br>
# *website* - project website <br>

# %%
node_type = "Project"

# %%
node_list = list(graph.nodes.match(node_type))
node_table = pd.DataFrame(node_list)
top_betw = node_table.sort_values(by=['betw'], ascending=False)
#Get first 15 nodes of the specified type
top_nodes = top_betw.head(15)
top_nodes
# Out:
#                  acronym          betw  ec_contribution        end_date_code  \
# 32035      GrapheneCore1  3.074818e+06         89000000  2018-03-31T00:00:00
# 21203           GRAPHENE  2.729211e+06         54000000  2016-03-31T00:00:00
# 8120         EGI-InSPIRE  2.452014e+06         25000000  2014-12-31T00:00:00
# 43829      GrapheneCore2  2.069696e+06         88000000  2020-03-31T00:00:00
# 21317                HBP  1.782999e+06         54000000  2017-02-28T00:00:00
# 34576           HBP SGA1  1.755587e+06         89000000  2018-03-31T00:00:00
# 645             EGEE-III  1.695839e+06         32000000  2010-04-30T00:00:00
# 46991           HBP SGA2  1.581863e+06         88000000  2020-03-31T00:00:00
# 30058  ELIXIR-EXCELERATE  1.228839e+06         19051482  2019-08-31T00:00:00
# 3465              ECHORD  1.174091e+06         18969760  2013-12-31T00:00:00
# 6427         PAST4FUTURE  1.079601e+06          6647909  2014-12-31T00:00:00
# 27318          AIDA-2020  1.039285e+06         10000000  2020-04-30T00:00:00
# 5481            EVIMALAR  1.024754e+06         12000000  2015-03-31T00:00:00
# 399              NANOSIL  1.014953e+06          4300000  2011-03-31T00:00:00
# 11885          PRACE-2IP  9.749067e+05         18000000  2014-08-31T00:00:00
#
#       framework                                       funded_under  \
# 32035     H2020  [EXCELLENT SCIENCE - Future and Emerging Techn...
# 21203       FP7  [Specific Programme "Cooperation": Information...
# 8120        FP7  [Specific Programme "Capacities": Research inf...
# 43829     H2020                                    [FET Flagships]
# 21317       FP7  [Specific Programme "Cooperation": Information...
# 34576     H2020  [EXCELLENT SCIENCE - Future and Emerging Techn...
# 645         FP7  [Specific Programme "Capacities": Research inf...
# 46991     H2020                                    [FET Flagships]
# 30058     H2020  [Developing new world-class research infrastru...
# 3465        FP7  [Specific Programme "Cooperation": Information...
# 6427        FP7  [Specific Programme "Cooperation": Environment...
# 27318     H2020  [Integrating and opening existing national and...
# 5481        FP7         [Specific Programme "Cooperation": Health]
# 399         FP7  [Specific Programme "Cooperation": Information...
# 11885       FP7  [Specific Programme "Capacities": Research inf...
#
#                                           funding_scheme  \
# 32035                                  SGA-RIA - SGA-RIA
# 21203  CPCSA - Combined Collaborative Project and Coo...
# 8120   CPCSA - Combined Collaborative Project and Coo...
# 43829                                  SGA-RIA - SGA-RIA
# 21317  CPCSA - Combined Collaborative Project and Coo...
# 34576                                  SGA-RIA - SGA-RIA
# 645    CPCSA - Combined Collaborative Project and Coo...
# 46991                                  SGA-RIA - SGA-RIA
# 30058               RIA - Research and Innovation action
# 3465                CP - Collaborative project (generic)
# 6427             CP-IP - Large-scale integrating project
# 27318               RIA - Research and Innovation action
# 5481                         NoE - Network of Excellence
# 399                          NoE - Network of Excellence
# 11885  CPCSA - Combined Collaborative Project and Coo...
#
#                                                objective  \
# 32035  This project is the second in the series of EC...
# 21203  This Flagship aims to take graphene and relate...
# 8120   Scientific research is no longer conducted wit...
# 43829  This proposal describes the third stage of the...
# 21317  Understanding the human brain is one of the gr...
# 34576  Understanding the human brain is one of the gr...
# 645    A globally distributed computing Grid now play...
# 46991  The Human Brain Project (HBP) is a major Europ...
# 30058  The life sciences are undergoing a transformat...
# 3465   The European robotics industry plays a key rol...
# 6427   Past4Future will combine multidisciplinary pal...
# 27318  Particle physics is at the forefront of the ER...
# 5481   This is a proposal from 55 partners from 36 in...
# 399    NANOSIL Network of Excellence aims to integrat...
# 11885  PRACE-2IP supports the accelerated implementat...
#
#                                      project_description     rcn  \
# 32035                                                     200853
# 21203  \nFET Flagships\nThe Graphene Flagship project...  109691
# 8120    \nDistributed computing infrastructure (DCI)\n\n   95923
# 43829                                                     216122
# 21317                                \nFET Flagships\n\n  109805
# 34576                                                     205371
# 645                 \ne-Science Grid infrastructures\n\n   87264
# 46991                                                     220793
# 30058                                                     198519
# 3465   \nCognitive Systems, Interaction, Robotics\nSt...   90429
# 6427                                                       94121
# 27318                                                     194944
# 5481                                                       93052
# 399    \nNext-Generation Nanoelectronics Components a...   85244
# 11885  \nSecond implementation phase of the European ...   99874
#
#            start_date_code   status  \
# 32035  2016-04-01T00:00:00      NaN
# 21203  2013-10-01T00:00:00   CLOSED
# 8120   2010-05-01T00:00:00   CLOSED
# 43829  2018-04-01T00:00:00  ONGOING
# 21317  2013-10-01T00:00:00   CLOSED
# 34576  2016-04-01T00:00:00   CLOSED
# 645    2008-05-01T00:00:00   CLOSED
# 46991  2018-04-01T00:00:00  ONGOING
# 30058  2015-09-01T00:00:00   CLOSED
# 3465   2009-01-01T00:00:00   CLOSED
# 6427   2010-01-01T00:00:00   CLOSED
# 27318  2015-05-01T00:00:00  ONGOING
# 5481   2009-10-01T00:00:00   CLOSED
# 399    2008-01-01T00:00:00   CLOSED
# 11885  2011-09-01T00:00:00   CLOSED
#
#                                                    title  total_cost  \
# 32035             Graphene-based disruptive technologies    89000000
# 21203       Graphene-Based Revolutions in ICT And Beyond    74979522
# 8120   European Grid Initiative: Integrated Sustainab...    70337893
# 43829                   Graphene Flagship Core Project 2    88000000
# 21317                            The Human Brain Project    72522840
# 34576     Human Brain Project Specific Grant Agreement 1    89000000
# 645                     Enabling Grids for E-sciencE III    49022472
# 46991     Human Brain Project Specific Grant Agreement 2    88000000
# 30058  ELIXIR-EXCELERATE: Fast-track ELIXIR implement...    19051482
# 3465   European Clearing House for Open Robotics Deve...    25841074
# 6427     Climate change - Learning from the past climate     9233878
# 27318  Advanced European Infrastructures for Detector...    12909987
# 5481   Towards the establishment of a permanent Europ...    16971764
# 399    Silicon-based nanostructures and nanodevices f...     5456404
# 11885        PRACE - Second Implementation Phase Project    35176359
#
#                                            website
# 32035                https://graphene-flagship.eu/
# 21203             http://www.graphene-flagship.eu/
# 8120
# 43829
# 21317
# 34576         https://www.humanbrainproject.eu/en/
# 645
# 46991
# 30058     https://www.elixir-europe.org/excelerate
# 3465   http://www.echord.info/wikis/home-wiki/home
# 6427                    http://www.past4future.eu/
# 27318                      http://cern.ch/aida2020
# 5481                      http://www.evimalar.org/
# 399
# 11885

# %%
 _s3_savetable(top_nodes, object_path=f'{node_type}/project_centrality_top15.csv')
