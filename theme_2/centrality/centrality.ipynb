# %% [markdown]
# ## Setting up database connection

# %% [markdown]
# Importing required python libraries

# %%
import py2neo
from nesta.core.luigihacks.misctools import get_config
from nesta.core.orms.orm_utils import graph_session
import igraph as ig
import pandas as pd

# %% [markdown]
# Establish connection to the Neo4j database

# %%
conf = get_config('neo4j.config', 'neo4j')
gkwargs = dict(host=conf['host'], secure=True,
                auth=(conf['user'], conf['password']))

# %% [markdown]
# ## Retrieving nodes from Neo4j

# %% [markdown]
# Create a graph object which will be used for our queries

# %%
with graph_session(**gkwargs) as tx:
    graph = tx.graph

# %% [markdown]
# Set the type of the node that should be retrieved. Available types are: "Project", "Organisation", "Publication", "Topic", "Report", "Datasets", "Software", "Proposal_Call". Simple change the word "Organisation" below to the required node type and re-run the cell.

# %%
node_type = "Organisation"

# %%
node_list = list(graph.nodes.match(node_type))
node_table = pd.DataFrame(node_list)
#Get first 5 nodes of the specified type
node_table.head(5)
# Out:
#        betw country_code    country_name        id  \
# 0  0.000747           GB  United Kingdom -99679701
# 1  0.724385           VN         Vietnam -99552481
# 2  0.733103           GR          Greece -99525116
# 3  0.947206           DK         Denmark -99524889
# 4  0.465352           CH     Switzerland -99449792
#
#                                  name
# 0    BAE SYSTEMS (OPERATIONS) LIMITED
# 1      Hanoi University of Technology
# 2  COSMOTE KINITES TILEPIKOINONIES AE
# 3  CONFEDERATION OF DANISH INDUSTRIES
# 4             Swiss Air Ambulance LTD

# %% [markdown]
# ## Sorting the results

# %% [markdown]
# To sort the table according to a column, simply make the variable "sort_column" equal to the column name (e.g. "betw")

# %%
sort_column = 'betw'

# %% [markdown]
# This gets top 10 nodes sorted in the descending order according to column "betw" (betweenness centrality)

# %%
sorted_table = node_table.sort_values(by=[sort_column], ascending=False)
sorted_table.head(10)
# Out:
#            betw country_code    country_name         id  \
# 8769   0.999999           DE         Germany  922470777
# 23798  0.999999           IL          Israel  953674610
# 30460  0.999979           DK         Denmark  972429172
# 50867  0.999968           GB  United Kingdom  999948557
# 7457   0.999919           US   United States  918469818
# 8432   0.999900           CO        Colombia  920903742
# 9748   0.999878           CN           China  925236829
# 35763  0.999870           DE         Germany  990692041
# 20644  0.999844           ES           Spain  951819388
# 37564  0.999804           PE            Peru  994990014
#
#                                              name
# 8769                                    RATH GMBH
# 23798            SINGER INSTRUMENTS & CONTROL LTD
# 30460                         CITOXLAB SCANTOX AS
# 50867                    ANDOR TECHNOLOGY LIMITED
# 7457   TOTAL E&P Research and Technology USA, LLC
# 8432      CORPORACION UNIVERSIDAD DE LA COSTA CUC
# 9748                            NINGBO UNIVERSITY
# 35763                                CROSSGATE AG
# 20644                          GALLETAS GULLON SA
# 37564            Investigaciones Medicas en Salud

# %% [markdown]
# ## Filtering the results

# %% [markdown]
# To filter the results table according to a column, simply make the variable "filter_column" equal to the column name (e.g. "country_code") and set the value of filter through the variable "filter_value".

# %%
filter_column = "country_code"
filter_value = "DE"

# %% [markdown]
# The example below shows first 10 organisations in Germany.

# %%
node_table.loc[node_table[filter_column] == filter_value]
node_table.head(10)
# Out:
#        betw country_code    country_name        id  \
# 0  0.000747           GB  United Kingdom -99679701
# 1  0.724385           VN         Vietnam -99552481
# 2  0.733103           GR          Greece -99525116
# 3  0.947206           DK         Denmark -99524889
# 4  0.465352           CH     Switzerland -99449792
# 5  0.178480           DE         Germany -98900625
# 6  0.626649           PL          Poland -98701641
# 7  0.068822           DE         Germany -98374997
# 8  0.866878           GR          Greece -97632515
# 9  0.050070           PL          Poland -96918953
#
#                                            name
# 0              BAE SYSTEMS (OPERATIONS) LIMITED
# 1                Hanoi University of Technology
# 2            COSMOTE KINITES TILEPIKOINONIES AE
# 3            CONFEDERATION OF DANISH INDUSTRIES
# 4                       Swiss Air Ambulance LTD
# 5             VDI/VDE INNOVATION + TECHNIK GMBH
# 6  SZCZECINECKA LOKALNA ORGANIZACJA TURYSTYCZNA
# 7                  UNIVERSITAETSKLINIKUM AACHEN
# 8                 INTRACOM SA TELECOM SOLUTIONS
# 9                      POLITECHNIKA KOSZALINSKA

# %% [markdown]
# The example below shows top10 organisations in Germany sorted by betweenness centrality

# %%
sorted_table.loc[sorted_table[filter_column] == filter_value]
sorted_table.head(10)
# Out:
#            betw country_code    country_name         id  \
# 8769   0.999999           DE         Germany  922470777
# 23798  0.999999           IL          Israel  953674610
# 30460  0.999979           DK         Denmark  972429172
# 50867  0.999968           GB  United Kingdom  999948557
# 7457   0.999919           US   United States  918469818
# 8432   0.999900           CO        Colombia  920903742
# 9748   0.999878           CN           China  925236829
# 35763  0.999870           DE         Germany  990692041
# 20644  0.999844           ES           Spain  951819388
# 37564  0.999804           PE            Peru  994990014
#
#                                              name
# 8769                                    RATH GMBH
# 23798            SINGER INSTRUMENTS & CONTROL LTD
# 30460                         CITOXLAB SCANTOX AS
# 50867                    ANDOR TECHNOLOGY LIMITED
# 7457   TOTAL E&P Research and Technology USA, LLC
# 8432      CORPORACION UNIVERSIDAD DE LA COSTA CUC
# 9748                            NINGBO UNIVERSITY
# 35763                                CROSSGATE AG
# 20644                          GALLETAS GULLON SA
# 37564            Investigaciones Medicas en Salud

# %% [markdown]
# ## Working with individual nodes

# %% [markdown]
# Find node by ID

# %%
found_node = graph.nodes.get(323063)

# %% [markdown]
# List all attributes of a node

# %%
print(found_node.keys())
# Out:
# dict_keys(['website', 'funded_under', 'total_cost', 'acronym', 'betw', 'ec_contribution', 'title', 'objective', 'project_description', 'framework', 'start_date_code', 'end_date_code', 'funding_scheme', 'rcn', 'status'])

# %% [markdown]
# Get attribute "acronym" of the reference node

# %%
print(found_node['acronym'])
# Out:
# i3DPost

# %% [markdown]
# Find nodes that are connected (i.e. have a relationship) to the node of reference

# %%
#find linked nodes where the reference node is start node
connected_nodes = list()
for rel in graph.match((None, found_node)):
    connected_nodes.append(rel.nodes)

# %%
#find linked nodes where the reference node is end node
connected_nodes = list()
for rel in graph.match((found_node, None )):
    connected_nodes.append(rel.nodes)

# %%
#find all nodes that have a HAS_PROJECT relationship to the reference node
connected_nodes = list()
for rel in graph.match((None, found_node), r_type="HAS_PROJECT"):
    connected_nodes.append(rel.nodes)

# %%
connected_nodes_table = pd.DataFrame(connected_nodes)
connected_nodes_table.head()
# Out:
#                                                    0  \
# 0  {'betw': 0.45848474349594937, 'title': 'FP7-IC...
# 1  {'betw': 0.13743845474192695, 'title': 'Intell...
# 2  {'betw': 0.8886491203588955, 'project_rcn': 85...
# 3  {'betw': 0.5459254756812018, 'project_rcn': 85...
# 4  {'betw': 0.7404681112068626, 'name': 'ETHNIKO ...
#
#                                                    1
# 0  {'website': 'http://www.i3dpost.eu', 'funded_u...
# 1  {'website': 'http://www.i3dpost.eu', 'funded_u...
# 2  {'website': 'http://www.i3dpost.eu', 'funded_u...
# 3  {'website': 'http://www.i3dpost.eu', 'funded_u...
# 4  {'website': 'http://www.i3dpost.eu', 'funded_u...

# %%
#filter nodes by property value
found_nodes = pd.DataFrame(list(graph.nodes.match("Project", ec_contribution__gt=1000000, status__not="CLOSED") ) )
found_nodes.head()
# Out:
#              acronym      betw  ec_contribution        end_date_code  \
# 0            GENESYS  0.815392          1079397  2010-04-12T00:00:00
# 1               IRMA  0.401757          2481395  2009-12-31T00:00:00
# 2            INSPIRE  0.399926          4979995  2014-01-31T00:00:00
# 3  NOVEL TOOLS IN PD  0.271529          1495400  2014-11-30T00:00:00
# 4              RDCVF  0.077114          2623333  2013-02-28T00:00:00
#
#   framework                                       funded_under  \
# 0       FP7  [Specific Programme "Cooperation": Information...
# 1       FP7  [Specific Programme "Cooperation": Information...
# 2       FP7  [Specific programme "People" implementing the ...
# 3       FP7  [Specific programme: "Ideas" implementing the ...
# 4       FP7         [Specific Programme "Cooperation": Health]
#
#                                       funding_scheme  \
# 0              CSA - Coordination and support action
# 1               CP - Collaborative project (generic)
# 2  MC-COFUND - Co-funding of Regional, National a...
# 3                        ERC-SG - ERC Starting Grant
# 4  CP-FP - Small or medium-scale focused research...
#
#                                            objective  \
# 0  So far, several EU funded projects and other i...
# 1  Disaster risk reduction policies and instituti...
# 2  The objective of this programme is to refine a...
# 3  To understand the molecular basis of any biolo...
# 4  The discovery of RdCVF (Rod-derived Cone Viabi...
#
#                                  project_description    rcn  \
# 0  \nICT for Environmental Management and Energy ...  87319
# 1  \nICT for Environmental Management and Energy ...  87828
# 2                                                     90290
# 3                                                     92856
# 4                                                     94464
#
#        start_date_code      status  \
# 0  2008-09-01T00:00:00  TERMINATED
# 1  2008-06-01T00:00:00  TERMINATED
# 2  2009-02-01T00:00:00  TERMINATED
# 3  2009-12-01T00:00:00  TERMINATED
# 4  2010-03-01T00:00:00  TERMINATED
#
#                                                title  total_cost  \
# 0  Good practices for European developers of adva...     1615300
# 1              Integrated Risk Management for Africa     3533633
# 2  IRCSET International Mobility Fellowships in S...    12449988
# 3  Novel tools for real time monitoring and quant...     1495400
# 4                  Rod-derived Cone Viability Factor     3934701
#
#                 website
# 0
# 1
# 2
# 3
# 4  http://www.rdcvf.eu/
